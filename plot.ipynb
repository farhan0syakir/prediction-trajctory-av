# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./result.txt')

# %%
print(df)
# Out:
#                                      my_name   my_value
# 0     model_lstm0_output_70000_plus_6000.pth  52.896162
# 1     model_lstm0_output_70000_plus_7000.pth  53.861578
# 2     model_lstm0_output_70000_plus_8000.pth  49.958260
# 3     model_lstm0_output_70000_plus_9000.pth  49.859042
# 4    model_lstm0_output_70000_plus_10000.pth  47.069059
# ..                                       ...        ...
# 344    model_lstm0_output_416k_plus_7000.pth  25.008785
# 345    model_lstm0_output_416k_plus_8000.pth  26.910025
# 346    model_lstm0_output_416k_plus_9000.pth  24.118956
# 347   model_lstm0_output_416k_plus_10000.pth  27.089822
# 348   model_lstm0_output_416k_plus_11000.pth  23.393010
#
# [349 rows x 2 columns]

# %%
# print(result['value'])
df.plot()
# plt.plot(result['value'].to_numpy())
# plt.ylabel('some numbers')
# plt.show()

# %%
# df
df.columns
df.nsmallest(5,'my_value')
# Out:
#                                      my_name   my_value
# 325   model_lstm0_output_360k_plus_37000.pth  21.701529
# 339    model_lstm0_output_416k_plus_2000.pth  21.758475
# 327   model_lstm0_output_360k_plus_39000.pth  22.115627
# 319   model_lstm0_output_360k_plus_31000.pth  22.179565
# 320   model_lstm0_output_360k_plus_32000.pth  22.355951

# %%
df['pandas_SMA'] = df.iloc[:,1].rolling(window=20).mean()

# %%
df['pandas_SMA'].plot()

# %%
df['pandas_SMA_100']
# Out:
# KeyErrorTraceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pandas_SMA_100'
#
# During handling of the above exception, another exception occurred:
#
# KeyErrorTraceback (most recent call last)
# <ipython-input-8-7bed0f75d67a> in <module>
# ----> 1 df['pandas_SMA_100']
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
# ...
